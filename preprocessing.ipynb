# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_json('output_indeed.json')

# %%
df=df[df.applymap(lambda x: x=="" or x==[])==False]

# %%
df
# Out:
#                                           COMPANY  \
# 0                                     Ride.Swiggy
# 1                                          Indeed
# 2                    TM Inputs & Services Pvt Ltd
# 3                 PIXADOO VISUALS PRIVATE LIMITED
# 4                                     Nanua India
# 5              iTriangle Infotech Private Limited
# 6              iTriangle Infotech Private Limited
# 7                                Simpli Namdharis
# 8                                    Arissa India
# 9                                           Shell
# 10                                          UIDAI
# 11                 Global Management and Services
# 12                      DECCAPEL FASHIONS PVT LTD
# 13                                      SHARP NGO
# 14                                    Hexion Inc.
# 15                                         Indeed
# 16                                    Ride.Swiggy
# 17                         Syneos Health Clinical
# ...

# %%
df.head()
# Out:
#                            COMPANY  \
# 0                      Ride.Swiggy
# 1                           Indeed
# 2     TM Inputs & Services Pvt Ltd
# 3  PIXADOO VISUALS PRIVATE LIMITED
# 4                      Nanua India
#
#                                          DESCRIPTION  \
# 0   Candidates with prior experience in data entr...
# 1   We're seeking not only a great presenter but ...
# 2   The BEST part is that you get your incentives...
# 3   Minimum work experience of 3 - 4 years is man...
# 4   Mission It is our mission to support our clie...
#
#                                                 LINK              LOCATION  \
# 0  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6...  Bengaluru, Karnataka
# 1  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6...  Bengaluru, Karnataka
# 2  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6...  Bengaluru, Karnataka
# 3  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6...  Bengaluru, Karnataka
# ...

# %%
df.isna().head()
# Out:
#    COMPANY  DESCRIPTION   LINK  LOCATION  SALARY  TITLE  cluster
# 0    False        False  False     False   False  False    False
# 1    False        False  False     False   False  False    False
# 2    False        False  False     False   False  False    False
# 3    False        False  False     False   False  False    False
# 4    False        False  False      True    True  False    False

# %%
df.to_json('processed_output.json',orient='records')
